# %% [markdown]
# ## Data set link

# %% [markdown]
# https://www.kaggle.com/datasets/jimschacko/airlines-dataset-to-predict-a-delay

# %% [markdown]
# Features of data:
# * AIRLINE: Airline
# * Flight: Type of aircraft
# * AirportFrom: Airport from
# * AirportTo: Airport to
# * DayOfWeek: Day of the week
# * Time: Time of the flight

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('6mb_Dataset/airlines.csv')
df.head()
df['Airline'].unique()
df.shape
# df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 df = pd.read_csv('6mb_Dataset/airlines.csv')
#       2 df.head()
#       3 df['Airline'].unique()
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ## DATA SET LINK

# %% [markdown]
# https://www.kaggle.com/datasets/robikscube/flight-delay-dataset-20182022

# %% [markdown]
# Features of data:

# %%
df2 = pd.read_csv('year_wise/2009.csv')

# df2.head()

# %%
df2.shape
# Out:
# (6429338, 28)

# %% [markdown]
# ### what to keep
# * day of week
# * flight number
# * origin
# * destination
# * arr delay minutes

# %%
cleaned_df = df2[['FL_DATE','OP_CARRIER', 'OP_CARRIER_FL_NUM', 'ORIGIN', 'DEST', 'ARR_DELAY','DEP_DELAY']]

# %%
cleaned_df.head()
# Out:
#       FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  ARR_DELAY  DEP_DELAY
# 0  2009-01-01         XE               1204    DCA  EWR        4.0       -2.0
# 1  2009-01-01         XE               1206    EWR  IAD       -8.0       -1.0
# 2  2009-01-01         XE               1207    EWR  DCA       -9.0       -1.0
# 3  2009-01-01         XE               1208    DCA  EWR      -12.0        9.0
# 4  2009-01-01         XE               1209    IAD  EWR      -38.0      -10.0

# %%
# print airline code with number of appearences
cleaned_df['OP_CARRIER'].value_counts()
# plot dep delay vs op carrier
# Out:
# WN    1128947
# AA     550056
# OO     546195
# MQ     435670
# DL     426036
# US     412008
# UA     376272
# XE     309360
# EV     298696
# NW     292400
# 9E     262269
# CO     256446
# FL     249954
# YV     243060
# B6     194109
# OH     150970
# AS     137140
# F9      87002
# HA      72748
# Name: OP_CARRIER, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=cleaned_df['OP_CARRIER'].value_counts().index, y=cleaned_df['OP_CARRIER'].value_counts().values)
# Out:
# <AxesSubplot:>

# %%
# dot plot of dep delay vs op carrier
plt.figure(figsize=(12,6))
sns.stripplot(x=cleaned_df['OP_CARRIER'], y=cleaned_df['DEP_DELAY'])
# Out:
# <AxesSubplot:xlabel='OP_CARRIER', ylabel='DEP_DELAY'>

# %%
sns.stripplot(x=cleaned_df['ORIGIN'], y=cleaned_df['DEP_DELAY'])
# Out:
# <AxesSubplot:xlabel='ORIGIN', ylabel='DEP_DELAY'>

# %%
# draw a heatmap of correlation
plt.figure(figsize=(12,6))
sns.heatmap(cleaned_df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
# draw pie chart of origin
plt.figure(figsize=(12,6))
plt.pie(cleaned_df['ORIGIN'].value_counts().values, labels=cleaned_df['ORIGIN'].value_counts().index)
plt.show()
plt.pie(cleaned_df['DEST'].value_counts().values, labels=cleaned_df['DEST'].value_counts().index)
plt.show()

# %%
# final = open('C:/Vartika/Semester 5/ml/project/data_preprocesing/year_wise/final.csv', 'w')
# final = open('C:/Vartika/Semester 5/ml/project/data_preprocesing/year_wise/final.csv', 'a')
# out = open('C:/Vartika/Semester 5/ml/project/data_preprocesing/year_wise/out.csv', 'w')

# %%
df2 = pd.read_csv('year_wise/2018.csv')
df2.dropna()
cleaned_df = df2[['FL_DATE','OP_CARRIER', 'OP_CARRIER_FL_NUM', 'ORIGIN', 'DEST', 'ARR_DELAY','DEP_DELAY']]
cleaned_df = cleaned_df.sort_values(by='DEP_DELAY', ascending=True)
cleaned_df = cleaned_df.iloc[::10, :]
cleaned_df = cleaned_df.iloc[::10, :]
final_df = cleaned_df.iloc[::10, :]
print(final_df.shape)
# remove the empty rows
final.write(final_df.to_csv(index=False, header=True))
plt.figure(figsize=(18, 12))
plt.subplot(2, 2, 1)
sns.barplot(x=df2['OP_CARRIER'].value_counts().index, y=df2['OP_CARRIER'].value_counts().values)
plt.title('Bar Plot for df2')
plt.subplot(2, 2, 2)
sns.barplot(x=cleaned_df['OP_CARRIER'].value_counts().index, y=cleaned_df['OP_CARRIER'].value_counts().values)
plt.title('Bar Plot for cleaned_df')
plt.subplot(2, 2, 3)
sns.stripplot(x=df2['OP_CARRIER'], y=df2['DEP_DELAY'])
plt.title('Strip Plot for df2')
plt.subplot(2, 2, 4)
sns.stripplot(x=cleaned_df['OP_CARRIER'], y=cleaned_df['DEP_DELAY'])
plt.title('Strip Plot for cleaned_df')
plt.tight_layout()
plt.show()
# Out:
# (7214, 7)

# %%
# f = pd.read_csv('C:/Vartika/Semester 5/ml/project/data_preprocesing/year_wise/final.csv')
# f.head()
# # f.shape
#
# out = open('C:/Vartika/Semester 5/ml/project/data_preprocesing/year_wise/out.csv', 'a')
# with open('C:/Vartika/Semester 5/ml/project/data_preprocesing/year_wise/final.csv', 'r') as f:
#     for line in f:
#         if line.strip():
#             out.write(line)

# %%
out = pd.read_csv('C:/Vartika/Semester 5/ml/project/data_preprocesing/year_wise/out.csv')
out.head()
out.shape
# Out:
# (61562, 7)

# %%
out.dropna()
# check if there is any column where there is no value in arr delay
for i in range(out.shape[0]):
    if out['ARR_DELAY'].empty():
        print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [32], in <cell line: 3>()
#       2 # check if there is any column where there is no value in arr delay
#       3 for i in range(out.shape[0]):
# ----> 4     if out['ARR_DELAY'].empty():
#       5         print(i)
#
# TypeError: 'bool' object is not callable

# %% [markdown]
# ## Data preprocessing start

# %% [markdown]
# #### final.csv is the final dataset

# %%
df = pd.read_csv('C:/Vartika/Semester 5/ml/project/data_preprocesing/year_wise/final.csv')
df.head()
# Out:
#       FL_DATE OP_CARRIER OP_CARRIER_FL_NUM ORIGIN DEST ARR_DELAY DEP_DELAY
# 0  2009-02-07         9E              2302    EVV  DTW    -107.0     -96.0
# 1  2009-04-12         AS                70    JNU  SIT     -31.0     -23.0
# 2  2009-08-25         YV              7140    CHS  ORD     -36.0     -20.0
# 3  2009-09-28         HA                29    SEA  OGG      -6.0     -19.0
# 4  2009-01-15         US              2173    LGA  DCA       7.0     -18.0

# %%
df.describe()
# Out:
#            FL_DATE OP_CARRIER OP_CARRIER_FL_NUM ORIGIN   DEST ARR_DELAY  \
# count        61571      61571             61571  61571  61571     61571
# unique        3591         24              7061    347    342       459
# top     2011-06-10         WN                16    ATL    ATL      -9.0
# freq            49      12058                42   3891   3866      1938
#
#        DEP_DELAY
# count      61571
# unique       423
# top         -5.0
# freq        4686
